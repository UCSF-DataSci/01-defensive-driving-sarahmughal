# %% [markdown]
# # Part 2a: Add Logging
#
# Load and process patient data with BMI calculations.
#
# **Your task:** Add logging statements to track the data processing steps.
#
# ---
#
# ## Load data

# %%
import pandas as pd

# TODO: Import logging module
# TODO: Configure logging with basicConfig (level=INFO, format="%(levelname)s:%(message)s")
# TODO: Add logging.info() statement before reading CSV

import logging

logging.basicConfig(level=logging.INFO, format="%(levelname)s:%(message)s")
logging.info("Reading patient_intake.csv file")

df = pd.read_csv("data/patient_intake.csv")

# TODO: Add logging.info() statement after loading (mention number of rows loaded)

df.head()
logging.info(f"Loaded {len(df)} rows from patient_intake.csv")
# Out:
# INFO:Reading patient_intake.csv file
# INFO:Loaded 50 rows from patient_intake.csv

# %% [markdown]
# ---
#
# ## Calculate BMI

# %%
# TODO: Add logging.info() statement at start of BMI calculation
logging.info("Starting BMI calculation for patients")
df["height_m"] = df["height_cm"] / 100
df["bmi"] = df["weight_kg"] / (df["height_m"] ** 2)
df["bmi"] = df["bmi"].round(1)

# TODO: Add logging.info() statement after BMI calculation (mention BMI range)
df[["patient_id", "weight_kg", "height_cm", "bmi"]].head()
logging.info(
    "BMI calculation complete. BMI ranges from %.1f to %.1f",
    df["bmi"].min(),
    df["bmi"].max(),
)
# Out:
# INFO:Starting BMI calculation for patients
# INFO:BMI calculation complete. BMI ranges from 19.9 to 36.1

# %% [markdown]
# ---
#
# ## Categorize BMI

# %%
df["bmi_category"] = pd.cut(
    df["bmi"],
    bins=[0, 18.5, 25, 30, float("inf")],
    labels=["Underweight", "Normal", "Overweight", "Obese"],
    right=False,
)

df[["patient_id", "bmi", "bmi_category"]].head()
# Out:
#   patient_id   bmi bmi_category
# 0       P001  29.2   Overweight
# 1       P002  29.9   Overweight
# 2       P003  28.0   Overweight
# 3       P004  22.0       Normal
# 4       P005  23.0       Normal

# %% [markdown]
# ---
#
# ## Summary statistics

# %%
summary = df.groupby("bmi_category")["patient_id"].count()
print("\nBMI category distribution:")
print(summary)

high_risk = df[df["bmi"] > 30]
print(f"\nHigh-risk patients (BMI > 30): {len(high_risk)}")

# TODO: Add logging.info() statement summarizing processing completion
logging.info("BMI categorization complete. Processed %d patients.", len(df))
# Out:
# /var/folders/5w/6rlwfykx6274ngzhynds5b_h0000gn/T/ipykernel_48274/194575862.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bmi_category")["patient_id"].count()
# INFO:BMI categorization complete. Processed 50 patients.
# BMI category distribution:
# bmi_category
# Underweight     0
# Normal         15
# Overweight     21
# Obese          14
# Name: patient_id, dtype: int64
#
# High-risk patients (BMI > 30): 14
